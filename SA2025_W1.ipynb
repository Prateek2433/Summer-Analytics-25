# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
cars = pd.read_csv('Cars.csv')

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
cars.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
print(cars.columns)
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'horsepower_by_weight'],
#       dtype='object')

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#your code here
cars = pd.read_csv('Cars.csv', index_col = 'name')

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
print(cars['mpg'].unique())
# Out:
# [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
cars['horsepower_by_weight'] = cars['horsepower'] / cars['weight']
cars.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
#
#                            acceleration  model_year origin  \
# name
# chevrolet chevelle malibu          12.0          70    usa
# buick skylark 320                  11.5          70    usa
# plymouth satellite                 11.0          70    usa
# amc rebel sst                      12.0          70    usa
# ford torino                        10.5          70    usa
#
#                            horsepower_by_weight
# name
# chevrolet chevelle malibu              0.037100
# buick skylark 320                      0.044679
# plymouth satellite                     0.043655
# amc rebel sst                          0.043694
# ford torino                            0.040591

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
#your code here
cars_sorted=cars.sort_values(by='horsepower', ascending  = False)
cars_sorted.index[0]
# Out:
# 'pontiac grand prix'

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
#your code here
print((cars['mpg']>=35).sum())
# Out:
# 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
#your code here
cars[(cars['horsepower'] > 100) & (cars['weight'] < 3000)]['origin'].value_counts().idxmax()
# Out:
# 'usa'

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
mean_acc = cars[cars['origin'] == 'japan']['acceleration'].mean()
print(f"{mean_acc:.2f}")
# Out:
# 16.17

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
bestYear=cars.groupby('model_year')['mpg'].mean().idxmax()
print(bestYear)
# Out:
# 80

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
#your code here
aboveMedianMpg = cars[cars['mpg'] > cars['mpg'].median()]
print(aboveMedianMpg.sort_values(by='horsepower_by_weight', ascending  = False).index.tolist())
# Out:
# ['bmw 2002', 'datsun 280-zx', 'chevrolet citation', 'saab 99le', 'datsun 1200', 'toyota corona', 'oldsmobile omega brougham', 'opel 1900', 'datsun 510', 'toyota corolla 1600 (sw)', 'dodge colt hatchback custom', 'plymouth arrow gs', 'toyota corona hardtop', 'saab 99le', 'mazda rx-7 gs', 'datsun pl510', 'datsun pl510', 'datsun 810 maxima', 'nissan stanza xe', 'chevrolet citation', 'datsun 200-sx', 'datsun 510 (sw)', 'volkswagen rabbit custom', 'toyota corona mark ii', 'saab 99e', 'dodge colt m/m', 'toyota cressida', 'chevrolet vega 2300', 'fiat 124 sport coupe', 'honda civic', 'volkswagen rabbit', 'subaru', 'plymouth sapporo', 'datsun 200sx', 'datsun 710', 'datsun 510 hatchback', 'renault 12tl', 'dodge colt hardtop', 'dodge colt', 'audi fox', 'volkswagen rabbit l', 'buick century limited', 'buick opel isuzu deluxe', 'toyota corona', 'audi 100 ls', 'dodge colt (sw)', 'vw rabbit custom', 'fiat 124b', 'chevrolet cavalier 2-door', 'ford fiesta', 'toyota corolla 1200', 'dodge rampage', 'opel 1900', 'honda civic 1500 gl', 'vw rabbit', 'volkswagen rabbit', 'toyota celica gt', 'datsun f-10 hatchback', 'plymouth cricket', 'capri ii', 'volkswagen scirocco', 'audi 4000', 'volkswagen dasher', 'chrysler lebaron medallion', 'fiat 128', 'toyota corona', 'vw rabbit', 'dodge charger 2.2', 'toyota corolla 1200', 'dodge colt', 'plymouth reliant', 'pontiac phoenix', 'triumph tr7 coupe', 'datsun b-210', 'dodge aries wagon (sw)', 'dodge colt', 'fiat 131', 'toyota corolla', 'opel manta', 'toyota corolla', 'mazda glc custom', 'datsun b210', 'mazda glc 4', 'plymouth champ', 'volkswagen dasher', 'honda civic', 'honda civic (auto)', 'honda civic 1300', 'honda accord', 'honda prelude', 'opel manta', 'datsun b210 gx', 'volkswagen jetta', 'chevrolet cavalier', 'subaru dl', 'peugeot 304', 'plymouth reliant', 'buick skylark limited', 'dodge omni', 'chevrolet citation', 'vokswagen rabbit', 'datsun 310 gx', 'mazda glc custom l', 'fiat x1.9', 'fiat 124 tc', 'chevrolet cavalier wagon', 'honda civic cvcc', 'dodge aries se', 'honda accord cvcc', 'toyota corona liftback', 'toyota corolla liftback', 'toyota corolla', 'toyota starlet', 'chevrolet chevette', 'pontiac j2000 se hatchback', 'mercury lynx l', 'maxda glc deluxe', 'datsun 210 mpg', 'pontiac phoenix', 'volkswagen model 111', 'ford pinto', 'peugeot 504', 'plymouth horizon tc3', 'subaru', 'fiat strada custom', 'ford fairmont (man)', 'ford mustang ii 2+2', 'datsun 310', 'datsun 210', 'pontiac sunbird coupe', 'ford fairmont futura', 'volkswagen dasher', 'toyota corolla', 'buick skylark', 'honda accord lx', 'plymouth horizon', 'ford escort 4w', 'renault 5 gtl', 'chevrolet chevette', 'toyota corona', 'renault 12 (sw)', 'honda accord', 'subaru dl', 'toyota corolla', 'ford mustang gl', 'mazda glc', 'datsun 210', 'chevrolet chevette', 'ford fairmont', 'chevrolet camaro', 'toyota corolla tercel', 'datsun 710', 'toyota tercel', 'chevy s-10', 'ford ranger', 'amc concord', 'amc spirit dl', 'oldsmobile starfire sx', 'plymouth horizon miser', 'honda civic', 'honda civic cvcc', 'chevrolet vega', 'mazda 626', 'plymouth horizon 4', 'oldsmobile cutlass ciera (diesel)', 'oldsmobile cutlass ls', 'mazda 626', 'ford pinto', 'chevrolet woody', 'ford escort 2h', 'ford maverick', 'oldsmobile cutlass salon brougham', 'fiat 128', 'mazda glc deluxe', 'chevrolet chevette', 'volkswagen 1131 deluxe sedan', 'peugeot 505s turbo diesel', 'vw pickup', 'volkswagen rabbit custom diesel', 'volvo diesel', 'volkswagen super beetle', 'vw rabbit c (diesel)', 'audi 5000s (diesel)', 'peugeot 504', 'mercedes benz 300d', 'mercedes-benz 240d', 'vw dasher (diesel)', 'ford pinto', 'renault lecar deluxe', 'ford mustang cobra', 'renault 18i']

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
#your code here
grouped = cars.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()

origins = grouped['origin'].unique()

plt.figure(figsize=(10,6))

for origin in origins:
    data = grouped[grouped['origin'] == origin]
    plt.plot(data['model_year'], data['mpg'], marker='o', label=origin)

plt.title('Average MPG Over Years by Origin')
plt.xlabel('Year')
plt.ylabel('Average MPG')
plt.legend(title='Origin')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
#your code here
cars = cars.reset_index(drop=True)
cars.head()

hue_order = ['japan' , 'europe', 'usa']

plt.figure(figsize=(20, 20))
scatter = sns.scatterplot(
    data=cars,
    x='horsepower',
    y='weight',
    hue='origin',
    hue_order=hue_order,  
    size='mpg',
    sizes=(50, 300),
    legend='brief'
)

plt.title('Car Weight vs Horsepower by Origin with MPG Size', fontsize=16)
plt.xlabel('Horsepower')
plt.ylabel('Weight (lbs)')

plt.legend(title='Origin & MPG')  

plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
#your code here
import pandas as pd
final_cars = pd.read_csv('Cars.csv')

final_cars.head()
agg = final_cars.groupby('name').agg(
    model_year_count=pd.NamedAgg(column='model_year', aggfunc=lambda x: x.nunique()),
    mpg_std=pd.NamedAgg(column='mpg', aggfunc='std'),
    mpg_mean=pd.NamedAgg(column='mpg', aggfunc='mean')
).reset_index()

cars_with_std_lessthan_1 = agg[(agg['model_year_count'] >= 2) & (agg['mpg_std'] < 1.0)]


min_std = cars_with_std_lessthan_1['mpg_std'].min()


result = cars_with_std_lessthan_1[cars_with_std_lessthan_1['mpg_std'] == min_std]


result = result[['name', 'model_year_count', 'mpg_mean']]

print(result)
# Out:
#             name  model_year_count  mpg_mean
# 95  datsun pl510                 2      27.0

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
